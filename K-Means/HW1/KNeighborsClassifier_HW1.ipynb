# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Range of k values to test
k_range = range(1, 21)
avg_accuracies = []

# Iterate over k values from 1 to 20
for k in k_range:
    accuracies = []

    # Repeat at least five times for averaging
    for _ in range(5):
        # Split the data into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=None)

        # Initialize KNeighborsClassifier with current k
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)

        # Make predictions on the test set
        predictions = knn.predict(X_test)

        # Calculate accuracy and store it
        accuracy = accuracy_score(y_test, predictions)
        accuracies.append(accuracy)

    # Calculate and store the average accuracy for the current k
    avg_accuracy = np.mean(accuracies)
    avg_accuracies.append(avg_accuracy)
    print(f'Average accuracy for k={k}: {avg_accuracy:.2f}')

# Plot the line chart of k values vs average accuracies
plt.figure(figsize=(10, 6))
plt.plot(k_range, avg_accuracies, marker='o')
plt.title('K-Nearest Neighbors: Varying Number of Neighbors')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Average Accuracy')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# Average accuracy for k=1: 0.98
# Average accuracy for k=2: 0.96
# Average accuracy for k=3: 0.96
# Average accuracy for k=4: 0.95
# Average accuracy for k=5: 0.96
# Average accuracy for k=6: 0.96
# Average accuracy for k=7: 0.96
# Average accuracy for k=8: 0.96
# Average accuracy for k=9: 0.97
# Average accuracy for k=10: 0.96
# Average accuracy for k=11: 0.95
# Average accuracy for k=12: 0.96
# Average accuracy for k=13: 0.95
# Average accuracy for k=14: 0.96
# Average accuracy for k=15: 0.96
# Average accuracy for k=16: 0.96
# Average accuracy for k=17: 0.96
# Average accuracy for k=18: 0.95
# Average accuracy for k=19: 0.94
# Average accuracy for k=20: 0.94

# %%
# The chart reflects that initially 1 neighbor returns the highest accuracy. Whereas the accuracy continuously drops as k increases until around 5.
